# %% [markdown]
# <a href="https://colab.research.google.com/github/bahador1/BahadorColabNotes/blob/main/Qwen2_vl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/modelscope/ms-swift.git
# Out:
# Cloning into 'ms-swift'...
# remote: Enumerating objects: 82161, done.
# remote: Counting objects: 100% (2847/2847), done.
# remote: Compressing objects: 100% (1318/1318), done.
# remote: Total 82161 (delta 2383), reused 1537 (delta 1529), pack-reused 79314 (from 3)
# Receiving objects: 100% (82161/82161), 84.62 MiB | 25.61 MiB/s, done.
# Resolving deltas: 100% (62899/62899), done.

# %%
! pip install https://github.com/huggingface/transformers.git
# !pip install pyav qwen_vl_utils
# Out:
# ...
#      - 436.8 kB 17.7 MB/s 0:00:00
#   ERROR: Cannot unpack file /tmp/pip-unpack-rfzpwsub/transformers.git (downloaded from /tmp/pip-req-build-k7ahyh5c, content-type: text/html; charset=utf-8); cannot detect archive format
# ERROR: Cannot determine archive format of /tmp/pip-req-build-k7ahyh5c
# ERROR: Could not find a version that satisfies the requirement pyav (from versions: none)
# ERROR: No matching distribution found for pyav

# %%
# %cd ms-swift
# Out:
# /content/ms-swift

# %%
#now we instal everything for Fine-tuning
# !pip install -e .[llm]
# Out:
# Obtaining file:///content/ms-swift
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 3.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.8/298.8 kB 10.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
# WARNING: ms-swift 4.6.0.dev0 does not provide the extra 'llm'
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.9/42.9 kB 2.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.7/89.7 kB 6.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 527.0/527.0 kB 22.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 94.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 531.0/531.0 kB 28.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 416.6/416.6 kB 22.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Image-OCR Fine-Tuning

# %%
#datset tha has imag and ocr extract and train your model with them

# %% [markdown]
# ## Image description Fine-Tuning
